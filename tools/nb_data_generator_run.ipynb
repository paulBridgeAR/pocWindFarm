# %%
import importlib
import data_generator as gen

# %%
importlib.reload(gen)
 
print(f"source   : {gen.SOURCE}")
print(f"raw      : {gen.RAW}")
print(f"manifest : {gen.MANIFEST}")
print(f"seed     : {gen.SEED}")

# %%
print(f"days in source : {len(gen.days_in_source())}")
print(f"days landed    : {len(gen.days_landed())}")
print(f"next to land   : {gen.next_day()}")

# %%
# %skip
gen.reset_landing()
print("landing zone cleared")
print(f"next to land: {gen.next_day()}")

# %%
result = gen.land_next(noise=True)
 
if result is None:
    print("nothing left to land - every source day is already in the raw zone")
else:
    day, rows, manifest = result
    print(f"landed {day}   rows={rows}   faults={len(manifest)}")
    for entry in manifest:
        print(f"  {entry['fault']:<18} turbine {entry['turbine_id']:>2}  {entry['timestamp']}")
    print(f"\nnext: {gen.next_day()}")

# %%
gen.summarise()

# %%
faults = gen.read_manifest()
print(f"{len(faults)} faults injected\n")
 
if faults:
    display(spark.createDataFrame(faults))

# %%
while gen.land_next(noise=True): pass
